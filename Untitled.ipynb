# %%
# !pip install torch torchvision torchaudio \
  --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp310-cp310-manylinux_2_28_x86_64.whl (905.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 MB 2.9 MB/s eta 0:00:0000:0100:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp310-cp310-manylinux_2_28_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 96.3 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp310-cp310-manylinux_2_28_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 99.9 MB/s eta 0:00:00
# Collecting fsspec
#   Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 KB 6.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 68.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu11==10.3.0.86
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 35.2 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.3.1
#   Downloading https://download.pytorch.org/whl/triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 15.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.8.86
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.env/lib/python3.10/site-packages (from torch) (4.15.0)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 13.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in ./.env/lib/python3.10/site-packages (from torch) (3.1.6)
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 105.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.8.89
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 KB 105.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==9.1.0.70
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu11==11.4.1.48
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 17.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu11==11.7.5.86
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 12.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.11.3.6
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 6.1 MB/s eta 0:00:0000:0100:01
# Collecting filelock
#   Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 74.9 MB/s eta 0:00:00:00:01
# Collecting nvidia-nccl-cu11==2.21.5
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.21.5-py3-none-manylinux2014_x86_64.whl (147.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 16.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu11==11.8.87
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 101.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools>=40.8.0 in ./.env/lib/python3.10/site-packages (from triton==3.3.1->torch) (59.6.0)
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 116.3 MB/s eta 0:00:0000:0100:01
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 72.2 MB/s eta 0:00:00a 0:00:01
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 86.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# Installing collected packages: mpmath, triton, sympy, pillow, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numpy, networkx, fsspec, filelock, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch, torchvision, torchaudio
# Successfully installed filelock-3.20.0 fsspec-2025.12.0 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.1.0.70 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.21.5 nvidia-nvtx-cu11-11.8.86 pillow-12.0.0 sympy-1.14.0 torch-2.7.1+cu118 torchaudio-2.7.1+cu118 torchvision-0.22.1+cu118 triton-3.3.1

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.1.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.7.1+cu118)
# Requirement already satisfied: torchvision>=0.16.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.22.1+cu118)
# Requirement already satisfied: torchaudio>=2.1.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.7.1+cu118)
# Requirement already satisfied: transformers>=4.36.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: accelerate>=0.25.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.12.0)
# Requirement already satisfied: tokenizers>=0.15.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.22.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: numpy>=1.24.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2.2.6)
# Requirement already satisfied: tqdm>=4.66.0 in ./.env/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (4.67.3)
# Collecting datasets>=2.20.0
#   Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 KB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (10.3.0.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.8.89)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.11.3.6)
# Requirement already satisfied: filelock in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.4.1.48)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (9.1.0.70)
# Requirement already satisfied: networkx in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (10.9.0.58)
# Requirement already satisfied: triton==3.3.1 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (3.3.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (2.21.5)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.8.87)
# Requirement already satisfied: fsspec in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.8.89)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.7.5.86)
# Requirement already satisfied: sympy>=1.13.3 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (11.8.86)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools>=40.8.0 in ./.env/lib/python3.10/site-packages (from triton==3.3.1->torch>=2.1.0->-r requirements.txt (line 2)) (59.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.env/lib/python3.10/site-packages (from torchvision>=0.16.0->-r requirements.txt (line 3)) (12.0.0)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.10/site-packages (from transformers>=4.36.0->-r requirements.txt (line 7)) (26.0)
# Requirement already satisfied: safetensors>=0.4.3 in ./.env/lib/python3.10/site-packages (from transformers>=4.36.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.env/lib/python3.10/site-packages (from transformers>=4.36.0->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: typer-slim in ./.env/lib/python3.10/site-packages (from transformers>=4.36.0->-r requirements.txt (line 7)) (0.21.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.env/lib/python3.10/site-packages (from transformers>=4.36.0->-r requirements.txt (line 7)) (2026.1.15)
# Requirement already satisfied: psutil in ./.env/lib/python3.10/site-packages (from accelerate>=0.25.0->-r requirements.txt (line 8)) (7.2.2)
# Requirement already satisfied: shellingham in ./.env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in ./.env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (1.2.0)
# Collecting fsspec[http]<=2025.10.0,>=2023.1.0
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 KB 59.6 MB/s eta 0:00:00
# Collecting dill<0.4.1,>=0.3.0
#   Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 KB 47.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.32.2 in ./.env/lib/python3.10/site-packages (from datasets>=2.20.0->-r requirements.txt (line 15)) (2.32.5)
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 96.0 MB/s eta 0:00:0000:0100:01
# Collecting xxhash
#   Downloading xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.2/193.2 KB 62.0 MB/s eta 0:00:00
# Collecting pyarrow>=21.0.0
#   Downloading pyarrow-23.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 MB 39.4 MB/s eta 0:00:0000:0100:01
# Collecting multiprocess<0.70.19
#   Downloading multiprocess-0.70.18-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 48.3 MB/s eta 0:00:00
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.13.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 116.6 MB/s eta 0:00:00
# Requirement already satisfied: idna in ./.env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (3.11)
# Requirement already satisfied: httpcore==1.* in ./.env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: certifi in ./.env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (2026.1.4)
# Requirement already satisfied: anyio in ./.env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (4.12.1)
# Requirement already satisfied: h11>=0.16 in ./.env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.20.0->-r requirements.txt (line 15)) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.env/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.20.0->-r requirements.txt (line 15)) (3.4.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.env/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.1.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.10/site-packages (from pandas->datasets>=2.20.0->-r requirements.txt (line 15)) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 86.5 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in ./.env/lib/python3.10/site-packages (from pandas->datasets>=2.20.0->-r requirements.txt (line 15)) (2025.3)
# Requirement already satisfied: click>=8.0.0 in ./.env/lib/python3.10/site-packages (from typer-slim->transformers>=4.36.0->-r requirements.txt (line 7)) (8.3.1)
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 KB 65.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in ./.env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 15)) (25.4.0)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.5/219.5 KB 59.6 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.9/196.9 KB 45.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.22.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.0/347.0 KB 73.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in ./.env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.20.0->-r requirements.txt (line 15)) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->-r requirements.txt (line 10)) (1.3.1)
# Installing collected packages: pytz, xxhash, pyarrow, propcache, multidict, fsspec, frozenlist, dill, async-timeout, aiohappyeyeballs, yarl, pandas, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.12.0
#     Uninstalling fsspec-2025.12.0:
#       Successfully uninstalled fsspec-2025.12.0
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 async-timeout-5.0.1 datasets-4.5.0 dill-0.4.0 frozenlist-1.8.0 fsspec-2025.10.0 multidict-6.7.1 multiprocess-0.70.18 pandas-2.3.3 propcache-0.4.1 pyarrow-23.0.0 pytz-2025.2 xxhash-3.6.0 yarl-1.22.0

# %%
import json
import random
from pathlib import Path

# %%
INPUT_FILE = "data/source/eng.train"
OUTPUT_GOLD = "data/gold/gold.json"
OUTPUT_RAW = "data/raw/raw.json"

NUM_GOLD = 200
NUM_RAW = 1200
RANDOM_SEED = 42

# %%
def parse_conll_file(filepath):
    """
    Parses a CoNLL-2003 formatted file into a list of sentences.
    Each sentence is a dict with tokens and ner_tags.
    """
    sentences = []
    tokens = []
    ner_tags = []

    with open(filepath, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            # Sentence boundary
            if not line:
                if tokens:
                    sentences.append({
                        "tokens": tokens,
                        "ner_tags": ner_tags
                    })
                    tokens = []
                    ner_tags = []
                continue

            # Ignore document markers
            if line.startswith("-DOCSTART-"):
                continue

            parts = line.split()
            if len(parts) < 4:
                # Malformed line, skip safely
                continue

            token = parts[0]
            ner = parts[-1]

            tokens.append(token)
            ner_tags.append(ner)

    # Catch last sentence if file doesn't end with newline
    if tokens:
        sentences.append({
            "tokens": tokens,
            "ner_tags": ner_tags
        })

    return sentences

# %%
def main():
    random.seed(RANDOM_SEED)

    sentences = parse_conll_file(INPUT_FILE)

    if len(sentences) < NUM_GOLD + NUM_RAW:
        raise ValueError(
            f"Not enough sentences in dataset: found {len(sentences)}"
        )

    random.shuffle(sentences)

    gold_sentences = sentences[:NUM_GOLD]
    raw_sentences = sentences[NUM_GOLD:NUM_GOLD + NUM_RAW]

    gold_data = [
        {
            "id": f"gold_{i:04d}",
            "tokens": s["tokens"],
            "ner_tags": s["ner_tags"]
        }
        for i, s in enumerate(gold_sentences)
    ]

    raw_data = [
        {
            "id": f"raw_{i:04d}",
            "tokens": s["tokens"]
        }
        for i, s in enumerate(raw_sentences)
    ]

    Path(OUTPUT_GOLD).parent.mkdir(parents=True, exist_ok=True)
    Path(OUTPUT_RAW).parent.mkdir(parents=True, exist_ok=True)

    with open(OUTPUT_GOLD, "w", encoding="utf-8") as f:
        json.dump(gold_data, f, indent=2)

    with open(OUTPUT_RAW, "w", encoding="utf-8") as f:
        json.dump(raw_data, f, indent=2)

    print(f"Saved {len(gold_data)} gold sentences → {OUTPUT_GOLD}")
    print(f"Saved {len(raw_data)} raw sentences → {OUTPUT_RAW}")


if __name__ == "__main__":
    main()
# Out:
# Saved 200 gold sentences → data/gold/gold.json
# Saved 1200 raw sentences → data/raw/raw.json

# %%
import json
from pathlib import Path
from typing import List
import re
import time
import json
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
MODEL_NAME = "mistralai/Mistral-7B-Instruct-v0.2"
RAW_FILE = "data/raw/raw.json"
OUTPUT_FILE = "data/synthetic/synthetic.json"

BATCH_SIZE = 4
MAX_NEW_TOKENS = 256
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
PROMPT_TEMPLATE = """You are a Named Entity Recognition (NER) expert.

Label the following sentence using IOB format.
Use only these entity tags in IOB format:
B-PER, I-PER, B-ORG, I-ORG, B-LOC, I-LOC, B-MISC, I-MISC, O

Tokens:
{tokens}

Return exactly one NER tag per token, in order.
Output format:
NER: tag1 tag2 tag3 ...
"""

VALID_TAGS = {
    "B-PER", "I-PER",
    "B-ORG", "I-ORG",
    "B-LOC", "I-LOC",
    "B-MISC", "I-MISC",
    "O"
}

def load_model():
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

    # IMPORTANT: Set pad token for decoder-only models
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        torch_dtype=torch.float16,
        device_map="auto"
    )

    # Tell model about padding token
    model.config.pad_token_id = tokenizer.pad_token_id

    return tokenizer, model


def build_prompt(tokens, tokenizer):
    messages = [
        {
            "role": "system",
            "content": "You are an expert Named Entity Recognition system."
        },
        {
            "role": "user",
            "content": PROMPT_TEMPLATE.format(tokens=" ".join(tokens))
        }
    ]

    return tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )


def parse_ner_output(text: str, num_tokens: int) -> List[str]:
    if "NER:" not in text:
        return ["O"] * num_tokens

    ner_part = text.split("NER:", 1)[1]

    # extract only valid IOB tags
    tags = re.findall(
        r"\b(B-PER|I-PER|B-ORG|I-ORG|B-LOC|I-LOC|B-MISC|I-MISC|O)\b",
        ner_part
    )

    if len(tags) < num_tokens:
        # pad if model under-produces
        tags = tags + ["O"] * (num_tokens - len(tags))
    else:
        tags = tags[:num_tokens]

    return tags


def main():
    tokenizer, model = load_model()

    with open(RAW_FILE, "r") as f:
        raw_data = json.load(f)

    synthetic_data = []

    num_batches = (len(raw_data) + BATCH_SIZE - 1) // BATCH_SIZE
    latencies = []  # seconds

    for i in tqdm(
        range(0, len(raw_data), BATCH_SIZE),
        total=num_batches,
        desc="LLM NER labeling",
        unit="batch"
    ):
        batch = raw_data[i:i + BATCH_SIZE]

        prompts = [build_prompt(item["tokens"], tokenizer) for item in batch]
        inputs = tokenizer(prompts, return_tensors="pt", padding=True).to(DEVICE)

        # IMPORTANT: input length for slicing generated tokens
        input_len = inputs["input_ids"].shape[1]

        # ---- latency start ----
        torch.cuda.synchronize()
        start = time.perf_counter()

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=MAX_NEW_TOKENS,
                do_sample=False
            )

        torch.cuda.synchronize()
        end = time.perf_counter()
        # ---- latency end ----

        latencies.append(end - start)

        decoded = tokenizer.batch_decode(
            outputs[:, input_len:],  
            skip_special_tokens=True
        )

        for item, output_text in zip(batch, decoded):
            ner_tags = parse_ner_output(output_text, len(item["tokens"]))

            synthetic_data.append({
                "id": item["id"],
                "tokens": item["tokens"],
                "ner_tags": ner_tags
            })
    
    lat = np.array(latencies)

    with open("latency_mistral_llm.json", "w") as f:
        json.dump(
            {
                "unit": "seconds_per_batch",
                "min": float(lat.min()),
                "max": float(lat.max()),
                "avg": float(lat.mean()),
                "p95": float(np.percentile(lat, 95)),
                "batches": len(latencies),
                "batch_size": BATCH_SIZE
            },
            f,
            indent=2
        )
    
    Path(OUTPUT_FILE).parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_FILE, "w") as f:
        json.dump(synthetic_data, f, indent=2)
    
    print(f"Generated {len(synthetic_data)} synthetic samples → {OUTPUT_FILE}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ...
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generated 1200 synthetic samples → data/synthetic/synthetic.json

# %%
import json
from pathlib import Path

import numpy as np
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForTokenClassification,
    DataCollatorForTokenClassification,
    TrainingArguments,
    Trainer
)

# %%
MODEL_NAME = "distilbert-base-cased"
OUTPUT_DIR = "models/student-ner"

GOLD_FILE = "data/gold/gold.json"
SYNTH_FILE = "data/synthetic/synthetic.json"

MAX_LENGTH = 128

# %%
LABEL_LIST = [
    "O",
    "B-PER", "I-PER",
    "B-ORG", "I-ORG",
    "B-LOC", "I-LOC",
    "B-MISC", "I-MISC"
]

label2id = {l: i for i, l in enumerate(LABEL_LIST)}
id2label = {i: l for i, l in enumerate(LABEL_LIST)}

def load_data():
    with open(GOLD_FILE) as f:
        gold = json.load(f)
    with open(SYNTH_FILE) as f:
        synth = json.load(f)
    return gold, synth

'''
def build_label_mapping(samples):
    labels = set()
    for s in samples:
        labels.update(s["ner_tags"])
    label_list = sorted(labels)
    return {l: i for i, l in enumerate(label_list)}, label_list
'''

def tokenize_and_align_labels(examples, tokenizer, label2id):
    tokenized = tokenizer(
        examples["tokens"],
        truncation=True,
        is_split_into_words=True,
        max_length=MAX_LENGTH
    )

    labels = []
    for i, ner_tags in enumerate(examples["ner_tags"]):
        word_ids = tokenized.word_ids(batch_index=i)
        label_ids = []

        prev_word_id = None
        for word_id in word_ids:
            if word_id is None:
                label_ids.append(-100)
            elif word_id != prev_word_id:
                label_ids.append(label2id[ner_tags[word_id]])
            else:
                label_ids.append(-100)
            prev_word_id = word_id

        labels.append(label_ids)

    tokenized["labels"] = labels
    return tokenized

# %%
def main():
    gold, synth = load_data()

    all_samples = gold + synth
    #label2id, label_list = build_label_mapping(all_samples)

    dataset = Dataset.from_list(all_samples)

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

    data_collator = DataCollatorForTokenClassification(
        tokenizer=tokenizer,
        pad_to_multiple_of=8  # good for GPU efficiency
    )

    tokenized_ds = dataset.map(
        lambda x: tokenize_and_align_labels(x, tokenizer, label2id),
        batched=True
    )

    model = AutoModelForTokenClassification.from_pretrained(
        MODEL_NAME,
        num_labels=len(LABEL_LIST),
        id2label=id2label,
        label2id=label2id
    )

    args = TrainingArguments(
            output_dir=OUTPUT_DIR,
            learning_rate=5e-5,
            per_device_train_batch_size=16,
            num_train_epochs=3,
            weight_decay=0.01,
            logging_steps=50,
            save_strategy="epoch",
            fp16=True
    )

    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=tokenized_ds,
        data_collator=data_collator
    )
    
    trainer.train()
    model.save_pretrained(OUTPUT_DIR)
    tokenizer.save_pretrained(OUTPUT_DIR)

    print(f"Student model saved to {OUTPUT_DIR}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Map:   0%|          | 0/1400 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForTokenClassification LOAD REPORT from: distilbert-base-cased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#     <div>
#
#       <progress value='264' max='264' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [264/264 00:11, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.164494</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.380033</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.269447</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.258690</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.198146</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Student model saved to models/student-ner

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in ./.env/lib/python3.10/site-packages (from seqeval) (2.2.6)
# Collecting scikit-learn>=0.21.3
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 91.0 MB/s eta 0:00:00:00:0100:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 KB 78.0 MB/s eta 0:00:00
# Collecting scipy>=1.8.0
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 50.5 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=d08d64c676fc659b103f16c8d1bdb3d217f13e37e5dabc51c764c58f9caf8640
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, seqeval
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 scipy-1.15.3 seqeval-1.2.2 threadpoolctl-3.6.0

# %%
import torch
import time
import json
import numpy as np
from typing import List, Tuple
from pathlib import Path

from transformers import AutoTokenizer, AutoModelForTokenClassification
from seqeval.metrics import classification_report, f1_score, precision_score, recall_score
from tqdm import tqdm

# %%
# =====================
# Config
# =====================
MODEL_DIR = "models/student-ner"
EVAL_FILE = "data/source/eng.testa"
LATENCY_OUT = "metrics/student_latency.json"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# =====================
# Data parsing
# =====================
def parse_conll(filepath: str):
    """
    Parse CoNLL-2003 file into list of (tokens, tags)
    """
    sentences = []
    tokens, tags = [], []

    with open(filepath, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if not line:
                if tokens:
                    sentences.append((tokens, tags))
                    tokens, tags = [], []
                continue

            if line.startswith("-DOCSTART-"):
                continue

            parts = line.split()
            tokens.append(parts[0])
            tags.append(parts[-1])

    if tokens:
        sentences.append((tokens, tags))

    return sentences


# =====================
# Prediction + latency
# =====================
def predict_with_latency(
    model,
    tokenizer,
    tokens: List[str]
) -> Tuple[List[str], float]:
    """
    Token-level NER prediction with latency measurement.
    Returns:
      - aligned predictions (per word)
      - latency in milliseconds
    """

    encoding = tokenizer(
        tokens,
        is_split_into_words=True,
        return_tensors="pt",
        truncation=True
    )

    inputs = {k: v.to(DEVICE) for k, v in encoding.items()}

    # ---- latency start ----
    if torch.cuda.is_available():
        torch.cuda.synchronize()

    start = time.perf_counter()

    with torch.no_grad():
        outputs = model(**inputs)

    if torch.cuda.is_available():
        torch.cuda.synchronize()

    end = time.perf_counter()
    # ---- latency end ----

    latency_ms = (end - start) * 1000.0

    preds = outputs.logits.argmax(dim=-1)[0].tolist()
    word_ids = encoding.word_ids(batch_index=0)

    aligned_preds = []
    prev_word_id = None

    for pred_id, word_id in zip(preds, word_ids):
        if word_id is None:
            continue
        if word_id != prev_word_id:
            aligned_preds.append(model.config.id2label[pred_id])
            prev_word_id = word_id

    return aligned_preds, latency_ms

# %%
# =====================
# Main
# =====================
def main():
    tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR)

    model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR)
    model.to(DEVICE)
    model.eval()

    print("Model label mapping:", model.config.id2label)

    eval_data = parse_conll(EVAL_FILE)

    # ---- warm-up (important!) ----
    for _ in range(5):
        _ = predict_with_latency(model, tokenizer, eval_data[0][0])

    y_true, y_pred = [], []
    latencies = []
    per_sample_latency = []

    for idx, (tokens, gold_tags) in enumerate(
        tqdm(eval_data, desc="Student NER inference")
    ):
        preds, latency_ms = predict_with_latency(model, tokenizer, tokens)

        min_len = min(len(preds), len(gold_tags))
        y_pred.append(preds[:min_len])
        y_true.append(gold_tags[:min_len])

        latencies.append(latency_ms)
        per_sample_latency.append({
            "sentence_id": idx,
            "num_tokens": len(tokens),
            "latency_ms": latency_ms
        })

    # =====================
    # NER Metrics
    # =====================
    print("\n===== NER Evaluation Report =====\n")
    print(classification_report(y_true, y_pred))
    print("Overall Precision:", precision_score(y_true, y_pred))
    print("Overall Recall:   ", recall_score(y_true, y_pred))
    print("Overall F1:       ", f1_score(y_true, y_pred))

    # =====================
    # Latency Metrics
    # =====================
    latencies = np.array(latencies)

    latency_report = {
        "model": "student-ner",
        "device": DEVICE,
        "num_sentences": len(latencies),
        "latency_ms": {
            "min": float(latencies.min()),
            "max": float(latencies.max()),
            "avg": float(latencies.mean()),
            "p95": float(np.percentile(latencies, 95)),
            "p99": float(np.percentile(latencies, 99))
        },
        "per_sample": per_sample_latency
    }

    Path(LATENCY_OUT).parent.mkdir(parents=True, exist_ok=True)
    with open(LATENCY_OUT, "w") as f:
        json.dump(latency_report, f, indent=2)

    print(f"\n✅ Student latency report saved → {LATENCY_OUT}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# ===== NER Evaluation Report =====
# /home/ubuntu/ner-genai-distillation/.env/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ubuntu/ner-genai-distillation/.env/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          LOC       0.00      0.00      0.00      1837
#         MISC       0.00      0.00      0.00       922
#          ORG       0.00      0.00      0.00      1341
#          PER       0.00      0.00      0.00      1842
#
#    micro avg       0.00      0.00      0.00      5942
#    macro avg       0.00      0.00      0.00      5942
# weighted avg       0.00      0.00      0.00      5942
#
# Overall Precision: 0.0
# Overall Recall:    0.0
# /home/ubuntu/ner-genai-distillation/.env/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Overall F1:        0.0
